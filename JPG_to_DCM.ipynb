# %% [markdown]
# <a href="https://colab.research.google.com/github/amidayiera/Medical-Imaging/blob/master/JPG_to_DCM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reference:
# [PYPX](https://openbase.com/python/pypx)

# %%
pip install pypx
# Out:
# ...
#      |████████████████████████████████| 85 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 64 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 52.9 MB/s
# ...
#      |████████████████████████████████| 41 kB 375 kB/s
# ...
#      |████████████████████████████████| 87 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 114 kB 59.0 MB/s
# ...
#      |████████████████████████████████| 218 kB 42.1 MB/s
# ...
#      |████████████████████████████████| 634 kB 56.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 47.1 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for pypx: filename=pypx-3.4.12-py3-none-any.whl size=109746 sha256=00f0ca3bb50e4b9217f2801bef0562053a6eb6f5f7690ed8f36dbf1d16c030af
#   Stored in directory: /root/.cache/pip/wheels/f3/7f/5e/940d4013030a0a3cf0867bbf96022807975990097b37aea4e0
# ...

# %%
pip install dcmtk
# Out:
# ERROR: Could not find a version that satisfies the requirement dcmtk (from versions: none)
# ERROR: No matching distribution found for dcmtk

# %%
import os

# %%
command = "img2dcm 129_13healthy.jpeg 129_13healthy.dcm"
os.system(command)
# Out:
# 32512

# %%
type(command)
# Out:
# str

# %%
conda config --add channels defaults
conda config --add channels bioconda
conda config --add channels conda-forge
# Out:
#   File "<ipython-input-7-0f8377ecdda7>", line 1
#     conda config --add channels defaults
#                ^
# SyntaxError: invalid syntax

# %%
conda install dcmtk
# Out:
#   File "<ipython-input-8-43fb9a589ef9>", line 1
#     conda install dcmtk
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### **Reference**:
#
# [Guide to installing conda when using google colab](https://towardsdatascience.com/conda-google-colab-75f7c867a522)

# %%
# check python version
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %% [markdown]
# It is generally a good idea to unset the PYTHONPATH variable before intslling miniconda
#
# because it can cause problems if there are packages installed and accessible via directories included in the PYTHONPATH that are not compatible with the version of python included with miniconda

# %%
# unset python variable
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %% [markdown]
# **Code below:**
#
# download installer script and installs it into /usr/local
#
# does not install in the default ~/miniconda3
#
# ensures that conda and all its necessary dependencies are automatically availabel within google colab

# %%
# install miniconda
# %%bash
MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
MINICONDA_PREFIX=/usr/local
wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
chmod +x $MINICONDA_INSTALLER_SCRIPT
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 4.5.4

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %% [markdown]
# **Code below:**
#
# updates conda and its dependencies
#
# does not update python version

# %%
# updating conda
# %%bash
conda install --channel defaults conda python=3.6 --yes
conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     requests-2.27.1            |     pyhd3eb1b0_0          52 KB
#     tqdm-4.63.0                |     pyhd3eb1b0_0          80 KB
#     conda-package-handling-1.7.3|   py36h27cfd23_1         946 KB
#     idna-3.3                   |     pyhd3eb1b0_0          55 KB
#     brotlipy-0.7.0             |py36h27cfd23_1003         349 KB
#     pip-21.2.2                 |   py36h06a4308_0         2.1 MB
#     readline-8.1.2             |       h7f8727e_1         423 KB
#     certifi-2021.5.30          |   py36h06a4308_0         141 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
# ...

# %%
# confirm update
# !conda --version
# Out:
# conda 4.10.3

# %%
# update conda to latest version 4.11.0
# !conda update -n base -c defaults conda
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
# !python --version
# Out:
# Python 3.6.13 :: Anaconda, Inc.

# %% [markdown]
# **Appending to the 'sys.path' :**
#
# add the directory where conda will install packages to the list of directories that python willl search when looking for modules to import

# %%
import sys
# displays pre installed packages as well  '/usr/local/lib/python3.7/dist-packages'
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# packages installed by conda will be installed in this directory
# !ls  /usr/local/lib/python3.7/dist-packages
# Out:
# absl
# absl_py-1.0.0.dist-info
# alabaster
# alabaster-0.7.12.dist-info
# albumentations
# albumentations-0.1.12.dist-info
# altair
# altair-4.2.0.dist-info
# apiclient
# appdirs-1.4.4.dist-info
# appdirs.py
# apt
# apt_inst.cpython-37m-x86_64-linux-gnu.so
# apt_inst.pyi
# apt_pkg.cpython-37m-x86_64-linux-gnu.so
# apt_pkg.pyi
# aptsources
# argon2
# argon2_cffi-21.3.0.dist-info
# _argon2_cffi_bindings
# argon2_cffi_bindings-21.2.0.dist-info
# arviz
# arviz-0.12.0.dist-info
# astor
# astor-0.8.1.dist-info
# astropy
# astropy-4.3.1.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# atari_py
# atari_py-0.2.9.dist-info
# atari_py.libs
# atomicwrites
# atomicwrites-1.4.0.dist-info
# attr
# attrs
# attrs-21.4.0.dist-info
# audioread
# audioread-2.1.9.dist-info
# autograd
# autograd-1.4.dist-info
# babel
# Babel-2.9.1.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.6.3.dist-info
# bin
# bleach
# bleach-5.0.0.dist-info
# blis
# blis-0.4.1.dist-info
# bokeh
# ...

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# | ^C

# %%
# !conda config --add channels default

# %% [markdown]
# [Convert JPG or PNG images into Dicom](https://pycad.co/convert-jpg-or-png-images-into-dicom/)
#
# [Install/Use conda on google colab](https://inside-machinelearning.com/en/how-to-install-use-conda-on-google-colab/)

# %% [markdown]
# pypx
#
# dcmtk
#
# convert jpg to dcm
#
# using miniconda

# %%
# !conda --version
# Out:
# conda 4.10.3

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 4.10.3

# %% [markdown]
# Reference : [Install *dcmtk*](https://bioconda.github.io/recipes/dcmtk/README.html)

# %%
# !conda config --add channels defaults

# %%
# activate bioconda channel
# !conda config --add channels bioconda

# %%
# !conda config --add channels conda-forge

# %%
# install dcmtk recipe
# !conda install dcmtk
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - dcmtk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     dcmtk-3.6.5                |       h6e3f024_1        11.4 MB  bioconda
#     gettext-0.19.8.1           |    h0b5b191_1005         3.6 MB  conda-forge
#     icu-68.2                   |       h9c3ff4c_0        13.1 MB  conda-forge
# ...

# %%
# !conda update dcmtk
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - dcmtk
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py36h8f6f2f9_1001         341 KB  conda-forge
#     charset-normalizer-2.0.12  |     pyhd8ed1ab_0          35 KB  conda-forge
#     colorama-0.4.4             |     pyh9f0ad1d_0          18 KB  conda-forge
#     cryptography-35.0.0        |   py36hb60f036_0         1.5 MB  conda-forge
#     idna-3.3                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     jbig-2.1                   |    h7f98852_2003          43 KB  conda-forge
# ...

# %%
# !conda update -n base conda
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.

# %%
# !dcmtk --version
# Out:
# /bin/bash: dcmtk: command not found

# %%
from google.colab import files
iploaded = files.upload()
# Out:
#      <input type="file" id="files-c6ecdd9d-21cc-428a-a667-ae8eb6b3594a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6ecdd9d-21cc-428a-a667-ae8eb6b3594a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 129_13healthy.jpeg to 129_13healthy.jpeg

# %%
# !img2dcm 129_13healthy.jpeg 129_13healthy.dcm

# %%
import os
command = "img2dcm 129_13healthy.jpeg 129_13healthy.dcm"
os.system(command)
# Out:
# 0

# %%
# !pip install pydicom
# !pip install dicom
# Out:
# ...
#   Using cached pydicom-2.3.0-py3-none-any.whl (2.0 MB)
# ...
#      |████████████████████████████████| 766 kB 8.2 MB/s
# ...

# %%
import pydicom

# %%
filepath = "/content/129_13healthy.dcm"

# %%
medical_image = pydicom.read_file(filepath)

# %%
print(medical_image)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7230010.3.1.4.481034752.10992.1650652954.180772
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Baseline (Process 1)
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.5
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_365'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.481034752.10992.1650652954.180772
# (0008, 0020) Study Date                          DA: ''
# ...
